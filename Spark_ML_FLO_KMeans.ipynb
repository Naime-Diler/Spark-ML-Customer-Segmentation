# %% [markdown]
# # Unüberwachtes Lernen und Kundensegmentierung mit Spark

# %% [markdown]
# ## Import the library and open a Spark session

# %%
import findspark

# %%
findspark.init("/opt/manual/spark")

# %%
from pyspark.sql import SparkSession, functions as F
import pandas as pd
import warnings

warnings.filterwarnings("ignore", category=FutureWarning)

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
spark = SparkSession.builder \
.appName("Clustering_KMeans") \
.master("local[*]") \
.config("spark.sql.shuffle.partitions", "2") \
.getOrCreate()

# %% [markdown]
# ## Read Data

# %%
df = spark.read.format("csv") \
.option("header", True) \
.option("delimiter", "|") \
.option("inferSchema", True) \
.load("/user/train/datasets/flo100k1.csv")

# %%
df.persist()
# Out:
# DataFrame[master_id: string, order_channel: string, platform_type: string, last_order_channel: string, first_order_date: timestamp, last_order_date: timestamp, last_order_date_online: timestamp, last_order_date_offline: timestamp, order_num_total_ever_online: double, order_num_total_ever_offline: double, customer_value_total_ever_offline: double, customer_value_total_ever_online: double, interested_in_categories_12: string, online_product_group_amount_top_name_12: string, offline_product_group_name_12: string, last_order_date_new: string, store_type: string]

# %% [markdown]
# ## Data Exploration

# %%
df.limit(5).toPandas()
# Out:
#                               master_id order_channel platform_type  \
# 0  b3ace094-a17f-11e9-a2fc-000d3a38a36f       Offline       Offline
# 1  c57d7c4c-a950-11e9-a2fc-000d3a38a36f       Offline   OmniChannel
# 2  602897a6-cdac-11ea-b31f-000d3a38a36f       Offline       Offline
# 3  388e4c4e-af86-11e9-a2fc-000d3a38a36f        Mobile        Online
# 4  80664354-adf0-11eb-8f64-000d3a299ebf       Desktop        Online
#
#   last_order_channel    first_order_date     last_order_date  \
# 0            Offline 2019-02-23 12:59:17 2019-02-23 12:59:17
# 1            Offline 2019-12-01 16:48:09 2019-12-01 16:48:09
# 2            Offline 2020-07-24 15:49:47 2020-07-24 15:49:47
# 3             Mobile 2018-12-31 07:22:07 2018-12-31 07:22:07
# 4            Desktop 2021-05-05 21:07:02 2021-05-05 22:39:36
#
#   last_order_date_online last_order_date_offline  order_num_total_ever_online  \
# 0                    NaT     2019-02-23 12:59:17                          NaN
# 1                    NaT     2019-12-01 16:48:09                          NaN
# 2                    NaT     2020-07-24 15:49:47                          NaN
# 3    2018-12-31 07:22:07                     NaT                          1.0
# 4    2021-05-05 22:39:36                     NaT                          2.0
#
#    order_num_total_ever_offline  customer_value_total_ever_offline  \
# 0                           1.0                             212.98
# 1                           1.0                             199.98
# 2                           1.0                             140.49
# 3                           NaN                               0.00
# 4                           NaN                               0.00
#
#    customer_value_total_ever_online interested_in_categories_12  \
# 0                              0.00                        None
# 1                              0.00                        None
# 2                              0.00                     [ERKEK]
# 3                            174.99                        None
# 4                            283.95                          []
#
#   online_product_group_amount_top_name_12 offline_product_group_name_12  \
# 0                                    None                          None
# 1                                    None                          None
# 2                                    None                         ERKEK
# 3                                    None                          None
# 4                                    None                          None
#
#   last_order_date_new store_type
# 0          2019-02-23          A
# 1          2019-12-01          A
# 2          2020-07-24          A
# 3          2018-12-31          A
# 4          2021-05-05          A

# %%
df.printSchema()
# Out:
# root
#  |-- master_id: string (nullable = true)
#  |-- order_channel: string (nullable = true)
#  |-- platform_type: string (nullable = true)
#  |-- last_order_channel: string (nullable = true)
#  |-- first_order_date: timestamp (nullable = true)
#  |-- last_order_date: timestamp (nullable = true)
#  |-- last_order_date_online: timestamp (nullable = true)
#  |-- last_order_date_offline: timestamp (nullable = true)
#  |-- order_num_total_ever_online: double (nullable = true)
#  |-- order_num_total_ever_offline: double (nullable = true)
#  |-- customer_value_total_ever_offline: double (nullable = true)
#  |-- customer_value_total_ever_online: double (nullable = true)
#  |-- interested_in_categories_12: string (nullable = true)
#  |-- online_product_group_amount_top_name_12: string (nullable = true)
#  |-- offline_product_group_name_12: string (nullable = true)
#  |-- last_order_date_new: string (nullable = true)
#  |-- store_type: string (nullable = true)

# %% [markdown]
# last_order_date_new: Wird als String angezeigt, sollte jedoch ein Timestamp sein. Da diese Variable für die weitere Analyse nicht relevant ist, kann sie so bleiben.

# %%
df_count = df.count()
print(f"Anzahl der gesamten Beobachtungen:", df_count)
# Out:
# Anzahl der gesamten Beobachtungen: 100000

# %%
num_variables = len(df.columns)
print(f"Anzahl der Variablen: {num_variables}")
# Out:
# Anzahl der Variablen: 17

# %% [markdown]
# ## Missing value check

# %%
df.select("interested_in_categories_12").show()
# Out:
# +---------------------------+
# |interested_in_categories_12|
# +---------------------------+
# |                       null|
# |                       null|
# |                    [ERKEK]|
# |                       null|
# |                         []|
# |                       null|
# |                [AKTIFSPOR]|
# |         [KADIN, AKTIFSPOR]|
# |             [ERKEK, KADIN]|
# |                         []|
# |                    [KADIN]|
# |                       null|
# |                       null|
# |                       null|
# |        [AKTIFCOCUK, KADIN]|
# |                       null|
# |                         []|
# |                [AKTIFSPOR]|
# |                       null|
# |                       null|
# +---------------------------+
# only showing top 20 rows

# %%
def null_count(df, col_name):
    nc = df.select(col_name).filter(
        (F.col(col_name) == "NaN") |
        (F.col(col_name) == "NaT") |
        (F.col(col_name) == "[]") |
        (F.col(col_name) == "") |
        (F.col(col_name).isNull())
                        ).count()
    return nc

# %%
for col_name in df.dtypes:
    nc = null_count(df, col_name[0])
    
    if nc > 0:
        print("{} has {} null values, or {:.2f}%.".format(col_name[0], nc, (nc/df_count)*100))
# Out:
# last_order_date_online has 70784 null values, or 70.78%.
# last_order_date_offline has 21703 null values, or 21.70%.
# order_num_total_ever_online has 70784 null values, or 70.78%.
# order_num_total_ever_offline has 21703 null values, or 21.70%.
# interested_in_categories_12 has 62371 null values, or 62.37%.
# online_product_group_amount_top_name_12 has 88295 null values, or 88.30%.
# offline_product_group_name_12 has 77209 null values, or 77.21%.

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# Ist die Variable `master_id` unique?:

# %%
unique_count = df.select("master_id").distinct().count()

if unique_count == df_count:
    print ("master_id is unique")
else: 
    print("master_id is not unique")
# Out:
# master_id is unique

# %% [markdown]
# ## Data Unterstanding

# %% [markdown]
# Beobachtungen werden nach `platform_type` und `order_channel` gezählt und sortiert.:

# %%
df.groupBy("platform_type", "order_channel").count().orderBy(F.desc("count")).show()
# Out:
# +-------------+-------------+-----+
# |platform_type|order_channel|count|
# +-------------+-------------+-----+
# |      Offline|      Offline|65991|
# |       Online|  Android App| 8728|
# |       Online|       Mobile| 6451|
# |  OmniChannel|      Offline| 4793|
# |  OmniChannel|  Android App| 3261|
# |       Online|      Desktop| 3253|
# |       Online|      Ios App| 3008|
# |  OmniChannel|       Mobile| 2061|
# |  OmniChannel|      Desktop| 1498|
# |  OmniChannel|      Ios App|  956|
# +-------------+-------------+-----+

# %% [markdown]
# ## Create new columns

# %% [markdown]
# Omnichannel-Kunden nutzen sowohl Online- als auch Offline-Plattformen für ihre Einkäufe.

# %% [markdown]
# Der Datentyp der Spalten `order_num_total_ever_online` und `order_num_total_ever_offline` wird von `double` auf `integer` geändert, um NaN-Werte bei der Erstellung der neuen Variable `NEW_order_num_total` zu vermeiden.

# %%
df.select("order_num_total_ever_online", "order_num_total_ever_offline").printSchema()
# Out:
# root
#  |-- order_num_total_ever_online: double (nullable = true)
#  |-- order_num_total_ever_offline: double (nullable = true)

# %%
df1 = df.withColumn("order_num_total_ever_online", F.when(F.col("order_num_total_ever_online").isNull(), 0).otherwise(F.col("order_num_total_ever_online"))) \
          .withColumn("order_num_total_ever_online", F.col("order_num_total_ever_online").cast("int")) \
         .withColumn("order_num_total_ever_offline", F.when(F.col("order_num_total_ever_offline").isNull(), 0).otherwise(F.col("order_num_total_ever_offline"))) \
          .withColumn("order_num_total_ever_offline", F.col("order_num_total_ever_offline").cast("int"))

# %%
# Kontrolle:

df1.select("order_num_total_ever_online", "order_num_total_ever_offline").printSchema()
# Out:
# root
#  |-- order_num_total_ever_online: integer (nullable = true)
#  |-- order_num_total_ever_offline: integer (nullable = true)

# %%
df1 = df.na.fill(value=0,
                subset=["order_num_total_ever_online", "order_num_total_ever_offline"])

# %% [markdown]
# **Alternative: Fehlende Werte durch den Mittelwert ersetzen.**
#
# Zunächst werden die Mittelwerte für jede betroffene Spalte berechnet:
#
# ```python
# from pyspark.sql.functions import expr
#
# df.selectExpr("AVG(order_num_total_ever_offline)").show()
# df.selectExpr("AVG(order_num_total_ever_online)").show()
# df.selectExpr("AVG(customer_value_total_ever_offline)").show()
# df.selectExpr("AVG(customer_value_total_ever_online)").show()
# ```
#
# Anschließend werden die berechneten Mittelwerte für die fehlenden Werte verwendet:
#
# ```python
# df1 = df.withColumn(
#     "customer_value_total_ever_online",
#     F.when(F.col("customer_value_total_ever_online") == "NA", 120).otherwise(F.col("customer_value_total_ever_online"))
# ).withColumn(
#     "customer_value_total_ever_offline",
#     F.when(F.col("customer_value_total_ever_offline") == "NA", 172).otherwise(F.col("customer_value_total_ever_offline"))
# ).withColumn(
#     "order_num_total_ever_online",
#     F.when(F.col("order_num_total_ever_online") == "NA", 3).otherwise(F.col("order_num_total_ever_online"))
# ).withColumn(
#     "order_num_total_ever_offline",
#     F.when(F.col("order_num_total_ever_offline") == "NA", 2).otherwise(F.col("order_num_total_ever_offline"))
# )
# ```

# %%
df1.limit(5).toPandas()
# Out:
#                               master_id order_channel platform_type  \
# 0  b3ace094-a17f-11e9-a2fc-000d3a38a36f       Offline       Offline
# 1  c57d7c4c-a950-11e9-a2fc-000d3a38a36f       Offline   OmniChannel
# 2  602897a6-cdac-11ea-b31f-000d3a38a36f       Offline       Offline
# 3  388e4c4e-af86-11e9-a2fc-000d3a38a36f        Mobile        Online
# 4  80664354-adf0-11eb-8f64-000d3a299ebf       Desktop        Online
#
#   last_order_channel    first_order_date     last_order_date  \
# 0            Offline 2019-02-23 12:59:17 2019-02-23 12:59:17
# 1            Offline 2019-12-01 16:48:09 2019-12-01 16:48:09
# 2            Offline 2020-07-24 15:49:47 2020-07-24 15:49:47
# 3             Mobile 2018-12-31 07:22:07 2018-12-31 07:22:07
# 4            Desktop 2021-05-05 21:07:02 2021-05-05 22:39:36
#
#   last_order_date_online last_order_date_offline  order_num_total_ever_online  \
# 0                    NaT     2019-02-23 12:59:17                          0.0
# 1                    NaT     2019-12-01 16:48:09                          0.0
# 2                    NaT     2020-07-24 15:49:47                          0.0
# 3    2018-12-31 07:22:07                     NaT                          1.0
# 4    2021-05-05 22:39:36                     NaT                          2.0
#
#    order_num_total_ever_offline  customer_value_total_ever_offline  \
# 0                           1.0                             212.98
# 1                           1.0                             199.98
# 2                           1.0                             140.49
# 3                           0.0                               0.00
# 4                           0.0                               0.00
#
#    customer_value_total_ever_online interested_in_categories_12  \
# 0                              0.00                        None
# 1                              0.00                        None
# 2                              0.00                     [ERKEK]
# 3                            174.99                        None
# 4                            283.95                          []
#
#   online_product_group_amount_top_name_12 offline_product_group_name_12  \
# 0                                    None                          None
# 1                                    None                          None
# 2                                    None                         ERKEK
# 3                                    None                          None
# 4                                    None                          None
#
#   last_order_date_new store_type
# 0          2019-02-23          A
# 1          2019-12-01          A
# 2          2020-07-24          A
# 3          2018-12-31          A
# 4          2021-05-05          A

# %% [markdown]
# Die Spalten `order_num_total_ever_online` und `order_num_total_ever_offline` wurden erneut automatisch als `double` formatiert.

# %%
# Neue Variable erstellen:

df1 = df1.withColumn('NEW_order_num_total',
                   df1.order_num_total_ever_online + df1.order_num_total_ever_offline)\
        .withColumn('NEW_customer_value_total', 
                   df1.customer_value_total_ever_offline + df1.customer_value_total_ever_online)

# %%
df1.limit(5).toPandas()
# Out:
#                               master_id order_channel platform_type  \
# 0  b3ace094-a17f-11e9-a2fc-000d3a38a36f       Offline       Offline
# 1  c57d7c4c-a950-11e9-a2fc-000d3a38a36f       Offline   OmniChannel
# 2  602897a6-cdac-11ea-b31f-000d3a38a36f       Offline       Offline
# 3  388e4c4e-af86-11e9-a2fc-000d3a38a36f        Mobile        Online
# 4  80664354-adf0-11eb-8f64-000d3a299ebf       Desktop        Online
#
#   last_order_channel    first_order_date     last_order_date  \
# 0            Offline 2019-02-23 12:59:17 2019-02-23 12:59:17
# 1            Offline 2019-12-01 16:48:09 2019-12-01 16:48:09
# 2            Offline 2020-07-24 15:49:47 2020-07-24 15:49:47
# 3             Mobile 2018-12-31 07:22:07 2018-12-31 07:22:07
# 4            Desktop 2021-05-05 21:07:02 2021-05-05 22:39:36
#
#   last_order_date_online last_order_date_offline  order_num_total_ever_online  \
# 0                    NaT     2019-02-23 12:59:17                          0.0
# 1                    NaT     2019-12-01 16:48:09                          0.0
# 2                    NaT     2020-07-24 15:49:47                          0.0
# 3    2018-12-31 07:22:07                     NaT                          1.0
# 4    2021-05-05 22:39:36                     NaT                          2.0
#
#    order_num_total_ever_offline  customer_value_total_ever_offline  \
# 0                           1.0                             212.98
# 1                           1.0                             199.98
# 2                           1.0                             140.49
# 3                           0.0                               0.00
# 4                           0.0                               0.00
#
#    customer_value_total_ever_online interested_in_categories_12  \
# 0                              0.00                        None
# 1                              0.00                        None
# 2                              0.00                     [ERKEK]
# 3                            174.99                        None
# 4                            283.95                          []
#
#   online_product_group_amount_top_name_12 offline_product_group_name_12  \
# 0                                    None                          None
# 1                                    None                          None
# 2                                    None                         ERKEK
# 3                                    None                          None
# 4                                    None                          None
#
#   last_order_date_new store_type  NEW_order_num_total  \
# 0          2019-02-23          A                  1.0
# 1          2019-12-01          A                  1.0
# 2          2020-07-24          A                  1.0
# 3          2018-12-31          A                  1.0
# 4          2021-05-05          A                  2.0
#
#    NEW_customer_value_total
# 0                    212.98
# 1                    199.98
# 2                    140.49
# 3                    174.99
# 4                    283.95

# %% [markdown]
# Kontrolle:
#
# Es dürfen keine Nullwerte in den Spalten `order_num_total_ever_online`, `order_num_total_ever_offline`, `customer_value_total_ever_offline`, `customer_value_total_ever_online`, `NEW_order_num_total` und `NEW_customer_value_total` auftreten.

# %%
for col_name in df1.dtypes:
    nc = null_count(df1, col_name[0])
    
    if nc > 0:
        print("{} has {} null values, or {:.2f}%.".format(col_name[0], nc, (nc/df_count)*100))
# Out:
# last_order_date_online has 70784 null values, or 70.78%.
# last_order_date_offline has 21703 null values, or 21.70%.
# interested_in_categories_12 has 62371 null values, or 62.37%.
# online_product_group_amount_top_name_12 has 88295 null values, or 88.30%.
# offline_product_group_name_12 has 77209 null values, or 77.21%.

# %% [markdown]
# ## Analysis `order_channel`

# %% [markdown]
# Die Verteilung der Gesamtzahl der Kunden, der durchschnittlich erhaltenen Produkte und der Einnahmen nach Kanälen (`order_channel`) wird betrachtet.

# %%
df1.groupby("order_channel").agg(
    F.count("master_id").alias("count(master_id)"),
    F.mean("NEW_order_num_total").alias("avg_NEW_order_num_total"),
    F.mean("NEW_customer_value_total").alias("avg_NEW_customer_value_total"),
    F.sum("NEW_customer_value_total").alias("sum_NEW_customer_value_total")
).show()
# Out:
# +-------------+----------------+-----------------------+----------------------------+----------------------------+
# |order_channel|count(master_id)|avg_NEW_order_num_total|avg_NEW_customer_value_total|sum_NEW_customer_value_total|
# +-------------+----------------+-----------------------+----------------------------+----------------------------+
# |      Offline|           70784|     1.6003475361663653|           218.1639484912399|        1.5442516930003924E7|
# |      Ios App|            3964|      3.377648839556004|           568.4640312815313|            2253391.41999999|
# |       Mobile|            8512|      2.798637218045113|           391.7418761748067|          3334506.8499999545|
# |      Desktop|            4751|      2.538623447695222|          376.91355504104155|          1790716.2999999884|
# |  Android App|           11989|       3.50971724080407|           532.8462840937418|            6388294.09999987|
# +-------------+----------------+-----------------------+----------------------------+----------------------------+

# %% [markdown]
# ## Analysis `platform_type`

# %% [markdown]
# Die Verteilung der Gesamtzahl der Kunden, der durchschnittlich erhaltenen Produkte und der Einnahmen auf den verschiedenen Plattformen wird betrachtet.

# %%
df1.groupby("platform_type").agg(
    F.count("master_id").alias("count(master_id)"),
    F.mean("NEW_order_num_total").alias("avg_NEW_order_num_total"),
    F.mean("NEW_customer_value_total").alias("avg_NEW_customer_value_total"),
    F.sum("NEW_customer_value_total").alias("sum_NEW_customer_value_total")
).show()
# Out:
# +-------------+----------------+-----------------------+----------------------------+----------------------------+
# |platform_type|count(master_id)|avg_NEW_order_num_total|avg_NEW_customer_value_total|sum_NEW_customer_value_total|
# +-------------+----------------+-----------------------+----------------------------+----------------------------+
# |      Offline|           65991|     1.5837917291751906|          215.73030686007337|        1.4236258680003101E7|
# |  OmniChannel|           12569|     3.4947092051873656|           500.7937512928511|           6294476.659999846|
# |       Online|           21440|     2.6207089552238805|           404.7896576492577|           8678690.260000085|
# +-------------+----------------+-----------------------+----------------------------+----------------------------+

# %% [markdown]
# ## Calculation of K-Means Metrics

# %% [markdown]
# ### RFM

# %%
rfm = df1.select(["master_id", "last_order_date_new", "NEW_order_num_total", "NEW_customer_value_total"])

# %%
rfm.limit(5).toPandas()
# Out:
#                               master_id last_order_date_new  \
# 0  b3ace094-a17f-11e9-a2fc-000d3a38a36f          2019-02-23
# 1  c57d7c4c-a950-11e9-a2fc-000d3a38a36f          2019-12-01
# 2  602897a6-cdac-11ea-b31f-000d3a38a36f          2020-07-24
# 3  388e4c4e-af86-11e9-a2fc-000d3a38a36f          2018-12-31
# 4  80664354-adf0-11eb-8f64-000d3a299ebf          2021-05-05
#
#    NEW_order_num_total  NEW_customer_value_total
# 0                  1.0                    212.98
# 1                  1.0                    199.98
# 2                  1.0                    140.49
# 3                  1.0                    174.99
# 4                  2.0                    283.95

# %%
from pyspark.sql.functions import max

# %%
last_order_date = df1.select(max("last_order_date")).collect()[0][0]

# %%
print("Das Datum des letzten Kaufs ist:", last_order_date)
# Out:
# Das Datum des letzten Kaufs ist: 2021-05-30 23:07:54

# %% [markdown]
# ### Recency

# %% [markdown]
# Die `Recency`-Spalte wird berechnet, indem die Anzahl der Tage zwischen `last_order_date_new` und `last_date_order` ermittelt und um 2 Tage erhöht wird.

# %%
from pyspark.sql.functions import expr

# %%
rfm1 = rfm.withColumn("Recency", F.expr(f"datediff('{last_order_date}', last_order_date_new) + 2"))

rfm1.limit(5).toPandas()
# Out:
#                               master_id last_order_date_new  \
# 0  b3ace094-a17f-11e9-a2fc-000d3a38a36f          2019-02-23
# 1  c57d7c4c-a950-11e9-a2fc-000d3a38a36f          2019-12-01
# 2  602897a6-cdac-11ea-b31f-000d3a38a36f          2020-07-24
# 3  388e4c4e-af86-11e9-a2fc-000d3a38a36f          2018-12-31
# 4  80664354-adf0-11eb-8f64-000d3a299ebf          2021-05-05
#
#    NEW_order_num_total  NEW_customer_value_total  Recency
# 0                  1.0                    212.98      829
# 1                  1.0                    199.98      548
# 2                  1.0                    140.49      312
# 3                  1.0                    174.99      883
# 4                  2.0                    283.95       27

# %% [markdown]
# ## Frequency and Monetary

# %%
rfm2 = (rfm1.withColumnRenamed("NEW_order_num_total", "Frequency") 
      .withColumnRenamed("NEW_customer_value_total", "Monetary")
      .drop("last_order_date_new"))

# %%
rfm2.limit(5).toPandas()
# Out:
#                               master_id  Frequency  Monetary  Recency
# 0  b3ace094-a17f-11e9-a2fc-000d3a38a36f        1.0    212.98      829
# 1  c57d7c4c-a950-11e9-a2fc-000d3a38a36f        1.0    199.98      548
# 2  602897a6-cdac-11ea-b31f-000d3a38a36f        1.0    140.49      312
# 3  388e4c4e-af86-11e9-a2fc-000d3a38a36f        1.0    174.99      883
# 4  80664354-adf0-11eb-8f64-000d3a299ebf        2.0    283.95       27

# %% [markdown]
# ## Model Preparation

# %% [markdown]
# ### Vector Assembler

# %% [markdown]
# Da rfm_cols = [`Frequency`, `Monetary`, `Recency`] bereits numerische Variablen sind, sind OneHotEncoder und StringIndexer nicht nötig. Es kann direkt der VectorAssembler verwendet werden.

# %%
rfm_cols = rfm2.columns[1:]

# %%
from pyspark.ml.feature import VectorAssembler

# %%
assembler =  VectorAssembler() \
              .setHandleInvalid("skip") \
              .setInputCols(rfm_cols) \
              .setOutputCol("unscaled_features")

# %% [markdown]
# ### Feature Scaler

# %%
from pyspark.ml.feature import StandardScaler

# %%
scaler = StandardScaler() \
.setInputCol("unscaled_features") \
.setOutputCol("features")

# %% [markdown]
# ### Pipeline

# %%
from pyspark.ml import Pipeline

# %%
pipeline_obj = Pipeline().setStages([assembler, scaler])

# %%
pipeline_model = pipeline_obj.fit(rfm2)

# %%
pipeline_df = pipeline_model.transform(rfm2)

# %%
pipeline_df.limit(5).toPandas()
# Out:
#                               master_id  Frequency  Monetary  Recency  \
# 0  b3ace094-a17f-11e9-a2fc-000d3a38a36f        1.0    212.98      829
# 1  c57d7c4c-a950-11e9-a2fc-000d3a38a36f        1.0    199.98      548
# 2  602897a6-cdac-11ea-b31f-000d3a38a36f        1.0    140.49      312
# 3  388e4c4e-af86-11e9-a2fc-000d3a38a36f        1.0    174.99      883
# 4  80664354-adf0-11eb-8f64-000d3a299ebf        2.0    283.95       27
#
#       unscaled_features                                           features
# 0  [1.0, 212.98, 829.0]  [0.32770120750468895, 0.4598810576445158, 3.24...
# 1  [1.0, 199.98, 548.0]  [0.32770120750468895, 0.43181056393910355, 2.1...
# 2  [1.0, 140.49, 312.0]  [0.32770120750468895, 0.30335566620564386, 1.2...
# 3  [1.0, 174.99, 883.0]  [0.32770120750468895, 0.37785043796231493, 3.4...
# 4   [2.0, 283.95, 27.0]  [0.6554024150093779, 0.6131243605886011, 0.105...

# %% [markdown]
# ## K-Means clustering model

# %% [markdown]
# Die optimale Anzahl an Clustern ermitteln.:

# %%
from pyspark.ml.clustering import KMeans

# %%
def compute_kmeans_model(df, k):
    kmeansObject = KMeans() \
    .setSeed(142) \
    .setK(k)
    
    return kmeansObject.fit(df)

# %% [markdown]
# ### Evaluator

# %%
from pyspark.ml.evaluation import ClusteringEvaluator

# %%
evaluator = ClusteringEvaluator()

# %%
for k in range(2,11):
    kmeans_model = compute_kmeans_model(pipeline_df, k)
    
    transformed_df = kmeans_model.transform(pipeline_df)
    
    score = evaluator.evaluate(transformed_df)
    
    print("k: {}, score: {}".format(k, score))
# Out:
# k: 2, score: 0.9995403313147956
# k: 3, score: 0.5306747271448232
# k: 4, score: 0.6705260499487317
# k: 5, score: 0.6839227157177052
# k: 6, score: 0.6561488711873166
# k: 7, score: 0.5487474862203171
# k: 8, score: 0.5154402600591739
# k: 9, score: 0.5690643226674137
# k: 10, score: 0.55055801154429

# %% [markdown]
# ## Prediction

# %%
kmeans_model = compute_kmeans_model(pipeline_df, 5)

# %%
transformed_df = kmeans_model.transform(pipeline_df)

# %%
transformed_df.limit(100).toPandas()
# Out:
#                                master_id  Frequency  Monetary  Recency  \
# 0   b3ace094-a17f-11e9-a2fc-000d3a38a36f        1.0    212.98      829
# 1   c57d7c4c-a950-11e9-a2fc-000d3a38a36f        1.0    199.98      548
# 2   602897a6-cdac-11ea-b31f-000d3a38a36f        1.0    140.49      312
# 3   388e4c4e-af86-11e9-a2fc-000d3a38a36f        1.0    174.99      883
# 4   80664354-adf0-11eb-8f64-000d3a299ebf        2.0    283.95       27
# 5   47511f36-aeb4-11e9-a2fc-000d3a38a36f        1.0    139.98      933
# 6   77f7c318-3407-11eb-9a15-000d3a38a36f        1.0    269.90      182
# 7   399d6dd2-ecf1-11ea-9369-000d3a38a36f        1.0     95.73      272
# 8   b3d4a6f2-a368-11e9-a2fc-000d3a38a36f        3.0    207.94      250
# 9   42fdccd4-f1d1-11ea-bde9-000d3a38a36f        1.0    134.95      226
# 10  071b497c-a5d2-11e9-a2fc-000d3a38a36f        7.0    399.94       71
# 11  47d99768-30ea-11ea-b884-000d3a38a36f        2.0    304.89      667
# 12  f879c85e-5322-11ea-acd3-000d3a38a36f        1.0    100.49      488
# 13  cfb38c70-b1e7-11e9-89fa-000d3a38a36f        3.0    208.96      507
# 14  96cae10c-bbd1-11ea-9a91-000d3a38a36f        2.0    359.96      335
# 15  20df63fa-5411-11ea-b1db-000d3a38a36f        1.0     39.99      501
# 16  757fc81a-7378-11ea-92d0-000d3a38a36f        2.0    630.94       67
# 17  c9fcbc34-d739-11ea-aceb-000d3a38a36f        1.0    289.99      300
# 18  9f44ad8c-21fc-11ea-ba6f-000d3a38a36f        1.0    189.99      788
# 92  afde8e88-3c8c-11ea-b550-000d3a38a36f        1.0     89.99      558
# 93  f725c0fa-d18c-11ea-a46d-000d3a38a36f        1.0     31.99      307
# 94  cafcc054-45d8-11ea-a691-000d3a38a36f        3.0    311.88      409
# 95  cafc89e0-24a4-11ea-bf27-000d3a38a36f        1.0     59.99      637
# 96  a1576ea4-1c3c-11ea-a490-000d3a38a36f        1.0     29.99      654
# 97  cad2d5a6-51cb-11ea-a243-000d3a38a36f        4.0    370.46      148
# 98  827a353a-5bf6-11ea-98c2-000d3a38a36f        2.0    167.98      188
# 99  ffc2b7ae-2129-11ea-b50a-000d3a38a36f        2.0    209.97      587
#
#                    unscaled_features  \
# 0               [1.0, 212.98, 829.0]
# 1               [1.0, 199.98, 548.0]
# 2               [1.0, 140.49, 312.0]
# 3               [1.0, 174.99, 883.0]
# 4                [2.0, 283.95, 27.0]
# 5               [1.0, 139.98, 933.0]
# 6                [1.0, 269.9, 182.0]
# 7                [1.0, 95.73, 272.0]
# 8               [3.0, 207.94, 250.0]
# 9               [1.0, 134.95, 226.0]
# 10               [7.0, 399.94, 71.0]
# 11              [2.0, 304.89, 667.0]
# 12              [1.0, 100.49, 488.0]
# 13  [3.0, 208.95999999999998, 507.0]
# 14              [2.0, 359.96, 335.0]
# 15               [1.0, 39.99, 501.0]
# 16               [2.0, 630.94, 67.0]
# 17              [1.0, 289.99, 300.0]
# 18              [1.0, 189.99, 788.0]
# 19               [1.0, 89.99, 385.0]
# 20               [1.0, 259.9, 802.0]
# 21              [1.0, 100.73, 471.0]
# 22              [2.0, 110.95, 351.0]
# 23               [3.0, 577.3, 462.0]
# 24              [4.0, 678.42, 131.0]
# 25              [1.0, 139.99, 605.0]
# 26              [1.0, 115.86, 103.0]
# 27               [1.0, 29.99, 643.0]
# 28              [1.0, 149.99, 812.0]
# 29              [3.0, 378.95, 354.0]
# 30               [1.0, 531.3, 394.0]
# 31                [2.0, 454.1, 31.0]
# 32              [1.0, 149.99, 518.0]
# 33                [1.0, 9.99, 563.0]
# 34              [1.0, 399.99, 305.0]
# 35              [3.0, 566.87, 348.0]
# 36              [1.0, 120.49, 451.0]
# 37               [1.0, 99.99, 679.0]
# 38              [1.0, 234.98, 217.0]
# 39  [4.0, 449.96000000000004, 545.0]
# 40               [1.0, 34.99, 678.0]
# 41                [1.0, 90.88, 95.0]
# 42              [1.0, 134.98, 568.0]
# 43                [1.0, 98.98, 84.0]
# 44              [2.0, 340.46, 447.0]
# 45              [7.0, 754.98, 977.0]
# 46              [3.0, 710.21, 158.0]
# 47              [1.0, 159.99, 556.0]
# 48              [1.0, 143.48, 472.0]
# 49            [11.0, 1242.02, 291.0]
# 50              [1.0, 339.99, 214.0]
# 51               [2.0, 99.99, 198.0]
# 52               [1.0, 49.99, 500.0]
# 53              [1.0, 197.98, 541.0]
# 54              [3.0, 833.94, 179.0]
# 55              [3.0, 229.97, 306.0]
# 56                [1.0, 69.29, 42.0]
# 57               [1.0, 49.99, 833.0]
# 58               [1.0, 170.97, 70.0]
# 59              [1.0, 149.99, 479.0]
# 60              [3.0, 339.97, 552.0]
# 61              [1.0, 129.99, 574.0]
# 62               [1.0, 89.99, 492.0]
# 63              [2.0, 360.72, 327.0]
# 64               [2.0, 713.4, 207.0]
# 65               [1.0, 83.97, 509.0]
# 66               [3.0, 129.97, 33.0]
# 67              [3.0, 174.93, 632.0]
# 68               [1.0, 19.99, 809.0]
# 69               [1.0, 49.98, 474.0]
# 70             [11.0, 1142.6, 285.0]
# 71              [1.0, 239.97, 745.0]
# 72              [1.0, 154.98, 570.0]
# 73              [1.0, 103.99, 204.0]
# 74               [1.0, 59.99, 488.0]
# 75              [1.0, 160.49, 316.0]
# 76               [1.0, 104.97, 56.0]
# 77                [5.0, 950.67, 6.0]
# 78              [2.0, 149.97, 245.0]
# 79               [1.0, 119.99, 64.0]
# 80              [1.0, 109.98, 334.0]
# 81               [1.0, 84.97, 642.0]
# 82              [1.0, 119.97, 130.0]
# 83              [1.0, 159.99, 280.0]
# 84                [2.0, 320.86, 8.0]
# 85               [1.0, 99.99, 638.0]
# 86               [1.0, 80.49, 321.0]
# 87              [3.0, 503.71, 347.0]
# 88               [1.0, 99.99, 299.0]
# 89              [1.0, 119.99, 544.0]
# 90              [3.0, 320.72, 223.0]
# 91              [1.0, 450.94, 133.0]
# 92               [1.0, 89.99, 558.0]
# 93               [1.0, 31.99, 307.0]
# 94              [3.0, 311.88, 409.0]
# 95               [1.0, 59.99, 637.0]
# 96               [1.0, 29.99, 654.0]
# 97              [4.0, 370.46, 148.0]
# 98              [2.0, 167.98, 188.0]
# 99              [2.0, 209.97, 587.0]
#
#                                              features  prediction
# 0   [0.32770120750468895, 0.4598810576445158, 3.24...           0
# 1   [0.32770120750468895, 0.43181056393910355, 2.1...           0
# 2   [0.32770120750468895, 0.30335566620564386, 1.2...           4
# 3   [0.32770120750468895, 0.37785043796231493, 3.4...           0
# 4   [0.6554024150093779, 0.6131243605886011, 0.105...           4
# 5   [0.32770120750468895, 0.30225443914489303, 3.6...           0
# 6   [0.32770120750468895, 0.5827866346992902, 0.71...           4
# 7   [0.32770120750468895, 0.20670679710916284, 1.0...           4
# 8   [0.9831036225140668, 0.44899834316180215, 0.97...           4
# 9   [0.32770120750468895, 0.2913933173496451, 0.88...           4
# 10  [2.293908452532823, 0.8635779425032757, 0.2781...           1
# 11  [0.6554024150093779, 0.6583394481417806, 2.613...           0
# 12  [0.32770120750468895, 0.21698491634283687, 1.9...           0
# 13  [0.9831036225140668, 0.4512007972833037, 1.986...           0
# 14  [0.6554024150093779, 0.7772503780154001, 1.312...           4
# 15  [0.32770120750468895, 0.08634915717534129, 1.9...           0
# 16  [0.6554024150093779, 1.3623690229609862, 0.262...           4
# 17  [0.32770120750468895, 0.626166343817885, 1.175...           4
# 18  [0.32770120750468895, 0.4102394691608675, 3.08...           0
# 19  [0.32770120750468895, 0.19431259450385002, 1.5...           4
# 67  [0.9831036225140668, 0.3777208818375207, 2.476...           0
# 68  [0.32770120750468895, 0.04316378224393779, 3.1...           0
# 69  [0.32770120750468895, 0.10792025195357734, 1.8...           0
# 70  [3.6047132825515784, 2.4671804698310815, 1.116...           1
# 71  [0.32770120750468895, 0.5181597211144449, 2.91...           0
# 72  [0.32770120750468895, 0.33464347034344566, 2.2...           0
# 73  [0.32770120750468895, 0.22454235695583247, 0.7...           4
# 74  [0.32770120750468895, 0.1295345321067448, 1.91...           0
# 75  [0.32770120750468895, 0.34654104113704737, 1.2...           4
# 76  [0.32770120750468895, 0.22665844032747126, 0.2...           4
# 77  [1.6385060375234448, 2.052752019301868, 0.0235...           1
# 78  [0.6554024150093779, 0.3238255339231291, 0.959...           4
# 79  [0.32770120750468895, 0.2590906569009553, 0.25...           4
# 80  [0.32770120750468895, 0.23747637674778785, 1.3...           4
# 81  [0.32770120750468895, 0.18347306539606775, 2.5...           0
# 82  [0.32770120750468895, 0.25904747152602386, 0.5...           4
# 83  [0.32770120750468895, 0.3454614067637623, 1.09...           4
# 84  [0.6554024150093779, 0.6928229700245063, 0.031...           4
# 85  [0.32770120750468895, 0.21590528196955178, 2.4...           0
# 86  [0.32770120750468895, 0.17379954141143336, 1.2...           4
# 87  [0.9831036225140668, 1.0876452603348628, 1.359...           4
# 88  [0.32770120750468895, 0.21590528196955178, 1.1...           4
# 89  [0.32770120750468895, 0.2590906569009553, 2.13...           0
# 90  [0.9831036225140668, 0.6925206723999865, 0.873...           4
# 91  [0.32770120750468895, 0.9737006485783546, 0.52...           4
# 92  [0.32770120750468895, 0.19431259450385002, 2.1...           0
# 93  [0.32770120750468895, 0.06907500720277988, 1.2...           4
# 94  [0.9831036225140668, 0.6734327366803061, 1.602...           4
# 95  [0.32770120750468895, 0.1295345321067448, 2.49...           0
# 96  [0.32770120750468895, 0.06475646970963954, 2.5...           0
# 97  [1.3108048300187558, 0.7999226998543869, 0.579...           4
# 98  [0.6554024150093779, 0.3627139640488579, 0.736...           4
# 99  [0.6554024150093779, 0.4533816587173396, 2.299...           0

# %% [markdown]
# ## Descriptive Statistic

# %%
from pyspark.sql.functions import sum, col, desc, mean, count

# %%
transformed_df.groupBy("prediction") \
  .agg(count("Monetary").alias('count'), \
       mean("Monetary").alias("avg_monetary"), \
       mean("Recency").alias("avg_recency"), \
       mean("Frequency").alias("avg_frequency")) \
  .sort(desc("avg_monetary")) \
  .show()
# Out:
# +----------+-----+------------------+------------------+------------------+
# |prediction|count|      avg_monetary|       avg_recency|     avg_frequency|
# +----------+-----+------------------+------------------+------------------+
# |         3|    6| 31003.60666666667|             343.5|226.83333333333334|
# |         2|  607|3211.2418945634286|185.09060955518945| 20.12685337726524|
# |         1| 7973| 994.4762122162238|192.21020945691708| 6.118901291860028|
# |         4|38165|255.77974950872283| 178.1563474387528| 1.742879601729333|
# |         0|53249|176.21715243480713|  618.113729835302|1.4225243666547729|
# +----------+-----+------------------+------------------+------------------+
